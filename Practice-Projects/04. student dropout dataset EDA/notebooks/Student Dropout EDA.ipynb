# %% [markdown]
# <div
# style="
# font-family: 'Roboto', sans-serif;
# color:white;
# background-color:#3f37c9;
# padding:1%;
# border-radius:10px;
# font-size:2em;
# text-align:center
# ">
# STUDENT DROPOUT DATASET
# </div>

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 📍 <b>NOTE</b>: This notebook is intended to :
# <ul>
#     <li>Provide exhaustive and comprehensive EDA on STUDENT DROPOUT dataset </li>
#     <li>Discuss the data-driven insights to the STUDENT DROPOUT dataset</li>
# </ul></div>

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔗 <b>Dataset link:</b> <a href="https://www.kaggle.com/datasets/abdullah0a/student-dropout-analysis-and-prediction-dataset">Click to download Dataset!</a>
# </div>

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# ⚓ <b>About the Dataset</b></br>
# <ol>
# <li><strong>School</strong>: Name of the school attended (e.g., MS).</li>
# <li><strong>Gender</strong>: Gender of the student (e.g., M for Male, F for Female).</li>
# <li><strong>Age</strong>: Age of the student.</li>
# <li><strong>Address</strong>: Type of residence (U for urban, R for rural).</li>
# <li><strong>Family_Size</strong>: Size of the family (GT3 for greater than 3, LE3 for less than or equal to 3).</li>
# <li><strong>Parental_Status</strong>: Living arrangement of parents (A  for living apart , T for living together).</li>
# <li><strong>Mother_Education</strong>: Education level of the mother (0 to 4).</li>
# <li><strong>Father_Education</strong>: Education level of the father (0 to 4).</li>
# <li><strong>Mother_Job</strong>: Type of job held by the mother.</li>
# <li><strong>Father_Job</strong>: Type of job held by the father.</li>
# <li><strong>Reason_for_Choosing_School</strong>: Reason for selecting the school (e.g., course).</li>
# <li><strong>Guardian</strong>: Guardian of the student (e.g., mother).</li>
# <li><strong>Travel_Time</strong>: Time taken to travel to school (in minutes).</li>
# <li><strong>Study_Time</strong>: Weekly study hours (1 to 4).</li>
# <li><strong>Number_of_Failures</strong>: Number of past class failures.</li>
# <li><strong>School_Support</strong>: Whether the student receives extra educational support (yes/no).</li>
# <li><strong>Family_Support</strong>: Family provided educational support (yes/no).</li>
# <li><strong>Extra_Paid_Class</strong>: Participation in extra paid classes (yes/no).</li>
# <li><strong>Extra_Curricular_Activities</strong>: Involvement in extracurricular activities (yes/no).</li>
# <li><strong>Attended_Nursery</strong>: Attendance in nursery school (yes/no).</li>
# <li><strong>Wants_Higher_Education</strong>: Desire to pursue higher education (yes/no).</li>
# <li><strong>Internet_Access</strong>: Availability of internet at home (yes/no).</li>
# <li><strong>In_Relationship</strong>: Romantic relationship status (yes/no).</li>
# <li><strong>Family_Relationship</strong>: Quality of family relationships (scale 1 to 5).</li>
# <li><strong>Free_Time</strong>: Amount of free time after school (scale 1 to 5).</li>
# <li><strong>Going_Out</strong>: Frequency of going out with friends (scale 1 to 5).</li>
# <li><strong>Weekend_Alcohol_Consumption</strong>: Alcohol consumption on weekends (scale 1 to 5).</li>
# <li><strong>Weekday_Alcohol_Consumption</strong>: Alcohol consumption on weekdays (scale 1 to 5).</li>
# <li><strong>Health_Status</strong>: Health rating of the student (scale 1 to 5).</li>
# <li><strong>Number_of_Absences</strong>: Total number of absences from school.</li>
# <li><strong>Grade_1</strong>: Grade received in the first assessment.</li>
# <li><strong>Grade_2</strong>: Grade received in the second assessment.</li>
# <li><strong>Final_Grade</strong>: Final grade received (G3).</li>
# <li><strong>Dropped_Out</strong>: Indicator of whether the student has dropped out (True/False).</li>
# </ol></div></div>
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import plotly.graph_objects as go
import plotly.subplots as sp

# %% [markdown]
# <div
# style="
# font-family: 'Roboto', sans-serif;
# color:white;
# background-color:#3f37c9;
# padding:1%;
# border-radius:10px;
# font-size:2em;
# text-align:center
# ">
# Initial Data Inspection
# </div>

# %%
dataframe = pd.read_csv('..\\data\\raw\\student dropout.csv')

# %%
df = dataframe.copy()

# %%
df.head(10)
# Out:
#   School Gender  Age Address Family_Size Parental_Status  Mother_Education  \
# 0     GP      F   18       U         GT3               A                 4
# 1     GP      F   17       U         GT3               T                 1
# 2     GP      F   15       U         LE3               T                 1
# 3     GP      F   15       U         GT3               T                 4
# 4     GP      F   16       U         GT3               T                 3
# 5     GP      M   16       U         LE3               T                 4
# 6     GP      M   16       U         LE3               T                 2
# 7     GP      F   17       U         GT3               A                 4
# 8     GP      M   15       U         LE3               A                 3
# 9     GP      M   15       U         GT3               T                 3
#
#    Father_Education Mother_Job Father_Job  ... Free_Time Going_Out  \
# 0                 4    at_home    teacher  ...         3         4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 34 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   School                       649 non-null    object
#  1   Gender                       649 non-null    object
#  2   Age                          649 non-null    int64
#  3   Address                      649 non-null    object
#  4   Family_Size                  649 non-null    object
#  5   Parental_Status              649 non-null    object
#  6   Mother_Education             649 non-null    int64
#  7   Father_Education             649 non-null    int64
#  8   Mother_Job                   649 non-null    object
#  9   Father_Job                   649 non-null    object
#  10  Reason_for_Choosing_School   649 non-null    object
#  11  Guardian                     649 non-null    object
#  12  Travel_Time                  649 non-null    int64
# ...

# %%
df.isnull().sum()
# Out:
# School                         0
# Gender                         0
# Age                            0
# Address                        0
# Family_Size                    0
# Parental_Status                0
# Mother_Education               0
# Father_Education               0
# Mother_Job                     0
# Father_Job                     0
# Reason_for_Choosing_School     0
# Guardian                       0
# Travel_Time                    0
# Study_Time                     0
# Number_of_Failures             0
# School_Support                 0
# Family_Support                 0
# Extra_Paid_Class               0
# Extra_Curricular_Activities    0
# Attended_Nursery               0
# Wants_Higher_Education         0
# Internet_Access                0
# In_Relationship                0
# Family_Relationship            0
# Free_Time                      0
# Going_Out                      0
# Weekend_Alcohol_Consumption    0
# Weekday_Alcohol_Consumption    0
# ...

# %%
df.describe()
# Out:
#               Age  Mother_Education  Father_Education  Travel_Time  \
# count  649.000000        649.000000        649.000000   649.000000
# mean    16.744222          2.514638          2.306626     1.568567
# std      1.218138          1.134552          1.099931     0.748660
# min     15.000000          0.000000          0.000000     1.000000
# 25%     16.000000          2.000000          1.000000     1.000000
# 50%     17.000000          2.000000          2.000000     1.000000
# 75%     18.000000          4.000000          3.000000     2.000000
# max     22.000000          4.000000          4.000000     4.000000
#
#        Study_Time  Number_of_Failures  Family_Relationship   Free_Time  \
# count  649.000000          649.000000           649.000000  649.000000
# mean     1.930663            0.221880             3.930663    3.180277
# std      0.829510            0.593235             0.955717    1.051093
# min      1.000000            0.000000             1.000000    1.000000
# ...

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>bool(1), int64(16), object(17)
#     <li>There are 649 entries in the dataset.</li>
#     <li>There are 16 numeric, 17 categorical and 1 boolian variable in the dataset.</li>
#     <li>There are no missing values in the dataset.</li>
#     <li>Dropped_Out variable can be considered to be the target variable whereas other variables can describe the various effects on it.</li>
# </ul></div>

# %%
for i in df.columns:
    print('--'*50)
    print(i)
    print(df[i].unique())
# Out:
# ----------------------------------------------------------------------------------------------------
# School
# ['GP' 'MS']
# ----------------------------------------------------------------------------------------------------
# Gender
# ['F' 'M']
# ----------------------------------------------------------------------------------------------------
# Age
# [18 17 15 16 19 22 20 21]
# ----------------------------------------------------------------------------------------------------
# Address
# ['U' 'R']
# ----------------------------------------------------------------------------------------------------
# Family_Size
# ['GT3' 'LE3']
# ----------------------------------------------------------------------------------------------------
# Parental_Status
# ['A' 'T']
# ----------------------------------------------------------------------------------------------------
# Mother_Education
# [4 1 3 2 0]
# ...

# %% [markdown]
# <div
# style="
# font-family: 'Roboto', sans-serif;
# color:white;
# background-color:#3f37c9;
# padding:1%;
# border-radius:10px;
# font-size:2em;
# text-align:center
# ">
# Cleaning Data for Analysis
# </div>

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>There is no need of any data wrrangling in this dataset.</li>
# </ul></div>

# %% [markdown]
# <div
# style="
# font-family: 'Roboto', sans-serif;
# color:white;
# background-color:#3f37c9;
# padding:1%;
# border-radius:10px;
# font-size:2em;
# text-align:center
# ">
# EXPLORATORY DATA ANALYSIS
# </div>

# %%
# using a custom style for my visualizations

plt.style.use('..\\references\\mystyle-v1.mplstyle')
# fig_size = (18, 6)

# %%
# getting all numerical variables
numerical_columns = []
for col in df.columns:
  if df[col].dtype != 'O':
    numerical_columns.append(col)
print(numerical_columns)
# Out:
# ['Age', 'Mother_Education', 'Father_Education', 'Travel_Time', 'Study_Time', 'Number_of_Failures', 'Family_Relationship', 'Free_Time', 'Going_Out', 'Weekend_Alcohol_Consumption', 'Weekday_Alcohol_Consumption', 'Health_Status', 'Number_of_Absences', 'Grade_1', 'Grade_2', 'Final_Grade', 'Dropped_Out']

# %%
# getting the catagorical variables
catagorical_columns = []
for col in df.columns:
  if df[col].dtype == 'O':
    catagorical_columns.append(col)
print(catagorical_columns)
# Out:
# ['School', 'Gender', 'Address', 'Family_Size', 'Parental_Status', 'Mother_Job', 'Father_Job', 'Reason_for_Choosing_School', 'Guardian', 'School_Support', 'Family_Support', 'Extra_Paid_Class', 'Extra_Curricular_Activities', 'Attended_Nursery', 'Wants_Higher_Education', 'Internet_Access', 'In_Relationship']

# %%
df_coloumns = list(df.columns)
print(df_coloumns)
# Out:
# ['School', 'Gender', 'Age', 'Address', 'Family_Size', 'Parental_Status', 'Mother_Education', 'Father_Education', 'Mother_Job', 'Father_Job', 'Reason_for_Choosing_School', 'Guardian', 'Travel_Time', 'Study_Time', 'Number_of_Failures', 'School_Support', 'Family_Support', 'Extra_Paid_Class', 'Extra_Curricular_Activities', 'Attended_Nursery', 'Wants_Higher_Education', 'Internet_Access', 'In_Relationship', 'Family_Relationship', 'Free_Time', 'Going_Out', 'Weekend_Alcohol_Consumption', 'Weekday_Alcohol_Consumption', 'Health_Status', 'Number_of_Absences', 'Grade_1', 'Grade_2', 'Final_Grade', 'Dropped_Out']

# %% [markdown]
# ## LET US SEE INDIVIDUAL VARIABLES AND THEIR RELASHIONSHIP

# %% [markdown]
# ### 1. School

# %%
print(f"IT IS A CATAGORICAL VARIABLE. \nUNIQUE VALUES IN {df_coloumns[0]} :{df[df_coloumns[0]].unique()}")
# Out:
# IT IS A CATAGORICAL VARIABLE.
# UNIQUE VALUES IN School :['GP' 'MS']

# %%
# Create bar chart figure
col_values = df[df_coloumns[0]].value_counts()
col_values = (col_values*100)//df.shape[0]
col_groups = col_values.index
fig = go.Figure(go.Bar(
    x= col_groups,
    y=col_values,
    marker_color="brown"
))

# Set overall title and axes labels
fig.update_layout(
    title_text=f'Bar Chart of {df_coloumns[0]}',
    xaxis_title='school name',
    yaxis_title='percentage of students',
)

# Style subplot
fig.update_layout(
    hovermode='x',  # Enable hover interaction
)

fig.show()

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>65% of students in this dataset are from GP school.</li>
#     <li>35% of students in this dataset are from MS school.</li>
# </ul></div>

# %%
school_col = df_coloumns[0]  # School column
gender_col = df_coloumns[1]  # Gender column

# Group by school and gender, and count the percentage of occurrences
gender_counts = df.groupby([school_col, gender_col]).size().fillna(0)
gender_counts = ((gender_counts*100)//df.shape[0]).unstack()

# Create the figure
fig = go.Figure()

# Add bars for each gender as separate traces, creating a stacked effect
for gender in gender_counts.columns:
    fig.add_trace(
        go.Bar(
            x=gender_counts.index,
            y=gender_counts[gender],
            name=str(gender),
            marker_color="orange" if gender == "M" else "deeppink"  # Different colors for each gender
        )
    )

# Update layout with stacked option
fig.update_layout(
    title_text=f'Bar Chart of {school_col} by {gender_col}',
    xaxis_title='School Name',
    yaxis_title='percentage of gender of Students',
    hovermode='x',
)

fig.show()

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>There are 36% Female and 28% Male students (out of 100% students) in GP school.</li>
#     <li>There are 22% Female and 12% Male students (out of 100% students) in MS school.</li>
# </ul></div>

# %%
school_col = df_coloumns[0]  # School column
age_col = df_coloumns[2]  # age column

# Group by school and age, and count the number of occurrences
age_counts = df.groupby([school_col, age_col]).size().fillna(0).unstack()

# Create the figure
fig = go.Figure()

# Add bars for each age as separate traces, creating a stacked effect
for age in age_counts.columns:
    fig.add_trace(
        go.Bar(
            x=age_counts.index,
            y=age_counts[age],
            name=str(age),
        )
    )

# Update layout with stacked option
fig.update_layout(
    title_text=f'Bar Chart of {school_col} by {age_col}',
    xaxis_title='School Name',
    yaxis_title='Number of Students',
)

fig.show()

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>Most of the students in GP school are of age 15 to 18 years.</li>
#     <li>Most of the students in MS school are of age 16 to 18 years.</li>
# </ul></div>

# %%
school_col = df_coloumns[0]  # School column
dropout_col = df_coloumns[33]  # dropout column

# Group by school and dropout, and count the percentage of occurrences
dropout_counts = df.groupby([school_col, dropout_col]).size().fillna(0).unstack()
dropout_counts = (dropout_counts*100)//df.shape[0]

# Create the figure
fig = go.Figure()

# Add bars for each dropout as separate traces, creating a stacked effect
for dropout in dropout_counts.columns:
    fig.add_trace(
        go.Bar(
            x=dropout_counts.index,
            y=dropout_counts[dropout],
            name=str(dropout),
            marker_color="orange" if dropout == True else "darkblue"  # Different colors for each dropout
        )
    )

# Update layout with stacked option
fig.update_layout(
    title_text=f'Bar Chart of {school_col} by {dropout_col}',
    xaxis_title='School Name',
    yaxis_title='percentage of dropout students',
)

fig.show()

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>Most of the dropouts are from MS school.</li>
# </ul></div>

# %% [markdown]
# ### 2. Gender

# %%
print(f"IT IS A CATAGORICAL VARIABLE. \nUNIQUE VALUES IN {df_coloumns[1]} :{df[df_coloumns[1]].unique()}")
# Out:
# IT IS A CATAGORICAL VARIABLE.
# UNIQUE VALUES IN Gender :['F' 'M']

# %%
# Create bar chart figure
col_values = df[df_coloumns[1]].value_counts()
col_values = (col_values*100)//df.shape[0]
col_groups = col_values.index
fig = go.Figure(go.Bar(
    x= col_groups,
    y=col_values,
    marker_color="blue"
))

# Set overall title and axes labels
fig.update_layout(
    title_text=f'Bar Chart of {df_coloumns[1]}',
    xaxis_title='Gender',
    yaxis_title='percentage of students',
)

# Style subplot
fig.update_layout(
    hovermode='x',  # Enable hover interaction
)

fig.show()

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>59% of students in this dataset are Females.</li>
#     <li>41% of students in this dataset are Males.</li>
# </ul></div>

# %%
gender_col = df_coloumns[1]  # Gender column
studytime_col = df_coloumns[13]  # dropout column

# Group by Gender and studytime, and count the percentage of occurrences
studytime_counts = df.groupby([gender_col, studytime_col]).size().fillna(0).unstack()
studytime_counts = (studytime_counts*100)//df.shape[0]

# Create the figure
fig = go.Figure()

# Add bars for each studytime as separate traces, creating a stacked effect
for studytime in studytime_counts.columns:
    fig.add_trace(
        go.Bar(
            x=studytime_counts.index,
            y=studytime_counts[studytime],
            name=str(studytime),
            # marker_color="orange" if studytime == True else "darkblue"  # Different colors for each studytime
        )
    )

# Update layout with stacked option
fig.update_layout(
    title_text=f'Bar Chart of {gender_col} by {studytime_col}',
    xaxis_title='Gender',
    yaxis_title='percentage of studytime of students',
)

fig.show()

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>Most Female students study for 2 hours per week.</li>
#     <li>Most Male Students study for 1 hour per week.</li>
# </ul></div>

# %%
gender_col = df_coloumns[1]  # Gender column
familysupport_col = df_coloumns[16]  # family support column

# Group by Gender and familysupport, and count the percentage of occurrences
familysupport_counts = df.groupby([gender_col, familysupport_col]).size().fillna(0).unstack()
familysupport_counts = (familysupport_counts*100)//df.shape[0]

# Create the figure
fig = go.Figure()

# Add bars for each familysupport as separate traces, creating a stacked effect
for familysupport in familysupport_counts.columns:
    fig.add_trace(
        go.Bar(
            x=familysupport_counts.index,
            y=familysupport_counts[familysupport],
            name=str(familysupport),
            marker_color="rebeccapurple" if familysupport == "yes" else "dodgerblue"  # Different colors for each familysupport
        )
    )

# Update layout with stacked option
fig.update_layout(
    title_text=f'Bar Chart of {gender_col} by {familysupport_col}',
    xaxis_title='Gender',
    yaxis_title='percentage of familysupport of students',
)

fig.show()

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>Most of the parents support their children in studies.</li>
# </ul></div>

# %%
gender_col = df_coloumns[1]  # Gender column
extracurricular_col = df_coloumns[18]  # Extra_Curricular_Activities column

# Group by Gender and extracurricular, and count the percentage of occurrences
extracurricular_counts = df.groupby([gender_col, extracurricular_col]).size().fillna(0).unstack()
extracurricular_counts = (extracurricular_counts*100)//df.shape[0]

# Create the figure
fig = go.Figure()

# Add bars for each extracurricular as separate traces, creating a stacked effect
for extracurricular in extracurricular_counts.columns:
    fig.add_trace(
        go.Bar(
            x=extracurricular_counts.index,
            y=extracurricular_counts[extracurricular],
            name=str(extracurricular),
            marker_color="limegreen" if extracurricular == "yes" else "gold"  # Different colors for each extracurricular
        )
    )

# Update layout with stacked option
fig.update_layout(
    title_text=f'Bar Chart of {gender_col} by {extracurricular_col}',
    xaxis_title='Gender',
    yaxis_title='percentage of extra curricular activities',
)

fig.show()

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>Boys take part in extra curricular activities more than girls.</li>
# </ul></div>

# %%
gender_col = df_coloumns[1]  # Gender column
higher_edu_col = df_coloumns[18]  # Wants_Higher_Education column

# Group by Gender and higher_edu, and count the percentage of occurrences
higher_edu_counts = df.groupby([gender_col, higher_edu_col]).size().fillna(0).unstack()
higher_edu_counts = (higher_edu_counts*100)//df.shape[0]

# Create the figure
fig = go.Figure()

# Add bars for each higher_edu as separate traces, creating a stacked effect
for higher_edu in higher_edu_counts.columns:
    fig.add_trace(
        go.Bar(
            x=higher_edu_counts.index,
            y=higher_edu_counts[higher_edu],
            name=str(higher_edu),
            marker_color="blue" if higher_edu == "yes" else "grey"  # Different colors for each higher_edu
        )
    )

# Update layout with stacked option
fig.update_layout(
    title_text=f'Bar Chart of {gender_col} by {higher_edu_col}',
    xaxis_title='Gender',
    yaxis_title='percentage of higher_education of students',
)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 gender_col = df_coloumns[1]  # Gender column
#       2 higher_edu_col = df_coloumns[18]  # Wants_Higher_Education column
#       4 # Group by Gender and higher_edu, and count the percentage of occurrences
#
# NameError: name 'df_coloumns' is not defined

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>Boys are willing to take higher education more than girls.</li>
# </ul></div>

# %% [markdown]
# ### 3. Age

# %%
print(f"IT IS A NUMERICAL VARIABLE. \nUNIQUE VALUES IN {df_coloumns[2]} :{df[df_coloumns[2]].unique()}")
# Out:
# IT IS A NUMERICAL VARIABLE.
# UNIQUE VALUES IN Age :[18 17 15 16 19 22 20 21]

# %%
fig = go.Figure(
        go.Histogram(
            x=df[df_coloumns[2]],
            marker = {"color": "magenta",
                      "line":{"width":1,"color":"black"}},
            histnorm= "percent",
))

# Set overall title and axes labels
fig.update_layout(
    title_text=f'Distribution of {df_coloumns[2]}',
    xaxis_title='Ages',
    yaxis_title='percentage',
)

# Style subplot
fig.update_layout(
    hovermode='x',  # Enable hover interaction
)

fig.show()

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>Most of the students in this dataset are of age 16 and 17.</li>
#     <li>The distribution of age is positively skewed.</li>
# </ul></div>

# %%
fig = go.Figure(
        go.Box(
            y=df[df_coloumns[2]],  # Note: y-axis for horizontal box plots
            boxpoints='all',  # Show all points
            marker_color="brown",
            showlegend=False,
            name= "Box Plot"
    
))

# Set overall title and axes labels
fig.update_layout(
    title_text=f'Boxplot of {df_coloumns[2]}',
    yaxis_title='ages',
)

# Style subplot
fig.update_layout(
    hovermode='x',  # Enable hover interaction
)

fig.show()

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>students of ages 21 and 22 can be our outliars.</li>
# </ul></div>

# %%
age_col = df_coloumns[2]  # Age column
dropout_col = df_coloumns[33]  # dropout column

# Group by Age and dropout, and count the percentage of occurrences
familysupport_counts = df.groupby([age_col, dropout_col]).size().fillna(0).unstack()
familysupport_counts = (familysupport_counts*100)//df.shape[0]

# Create the figure
fig = go.Figure()

# Add bars for each dropout as separate traces, creating a stacked effect
for dropout in familysupport_counts.columns:
    fig.add_trace(
        go.Bar(
            x=familysupport_counts.index,
            y=familysupport_counts[dropout],
            name=str(dropout),
            marker_color="red" if dropout == True else "grey"  # Different colors for each dropout
        )
    )

# Update layout with stacked option
fig.update_layout(
    title_text=f'Bar Chart of {age_col} by {dropout_col}',
    xaxis_title='Age',
    yaxis_title='percentage of dropout of students',
    hovermode='x',  # Enable hover interaction

)

fig.show()

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>dropouts are increasing in the ages 16,17 and 18.</li>
#     <li>Most dropouts are in the age 18.</li>
# </ul></div>

# %%
age_col = df_coloumns[2]  # Age column
inrelationship_col = df_coloumns[22]  # In_Relationship column

# Group by Age and relationship, and count the percentage of occurrences
relationship_counts = df.groupby([age_col, inrelationship_col]).size().fillna(0).unstack()
relationship_counts = (relationship_counts*100)//df.shape[0]

# Create the figure
fig = go.Figure()

# Add bars for each relationship as separate traces, creating a stacked effect
for relationship in relationship_counts.columns:
    fig.add_trace(
        go.Bar(
            x=relationship_counts.index,
            y=relationship_counts[relationship],
            name=str(relationship),
            marker_color="orange" if relationship == "yes" else "grey"  # Different colors for each relationship
        )
    )

# Update layout with stacked option
fig.update_layout(
    title_text=f'Bar Chart of {age_col} by {inrelationship_col}',
    xaxis_title='Age',
    yaxis_title='percentage of students in relationship',
    hovermode='x',  # Enable hover interaction
)

fig.show()

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>Most of the students are not in relationships.</li>
# </ul></div>

# %%
age_col = df_coloumns[2]  # Age column
family_relation_col = df_coloumns[23]  # family_Relation column

# Group by Age and family_relation, and count the percentage of occurrences
family_relation_counts = df.groupby([age_col, family_relation_col]).size().fillna(0).unstack()
family_relation_counts = (family_relation_counts*100)//df.shape[0]

# Create the figure
fig = go.Figure()

# Add bars for each family_relation as separate traces, creating a stacked effect
for family_relation in family_relation_counts.columns:
    fig.add_trace(
        go.Bar(
            x=family_relation_counts.index,
            y=family_relation_counts[family_relation],
            name=str(family_relation),
        )
    )

# Update layout with stacked option
fig.update_layout(
    title_text=f'Bar Chart of {age_col} by {family_relation_col}',
    xaxis_title='Age',
    yaxis_title='percentage of students and family relation',
    hovermode='x',  # Enable hover interaction
)

fig.show()

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>Most of the students are in a good relation with their family.</li>
# </ul></div>

# %% [markdown]
# ### 4. Grade 1

# %%
print(f"IT IS A NUMERICAL VARIABLE. \nUNIQUE VALUES IN {df_coloumns[30]} :{df[df_coloumns[30]].unique()}")
# Out:
# IT IS A NUMERICAL VARIABLE.
# UNIQUE VALUES IN Grade_1 :[ 0  9 12 14 11 13 10 15 17  8 16 18  7  6  5  4 19]

# %%
fig = go.Figure(
        go.Histogram(
            x=df[df_coloumns[30]],
            marker = {"color": "orange",
                      "line":{"width":1,"color":"black"}},
            histnorm= "percent",
))

# Set overall title and axes labels
fig.update_layout(
    title_text=f'Distribution of {df_coloumns[30]}',
    xaxis_title='Grades',
    yaxis_title='percentage',
)

# Style subplot
fig.update_layout(
    hovermode='x',  # Enable hover interaction
)

fig.show()

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>The distribution of Grade 1 is symmetrical.</li>
#     <li>The person with Grade 0 can be our outliar.</li>
# </ul></div>

# %%
fig = go.Figure(
        go.Box(
            y=df[df_coloumns[30]],  # Note: y-axis for horizontal box plots
            boxpoints='all',  # Show all points
            marker_color="red",
            showlegend=False,
            name= "Box Plot"
    
))

# Set overall title and axes labels
fig.update_layout(
    title_text=f'Boxplot of {df_coloumns[30]}',
    yaxis_title='grades',
)

# Style subplot
fig.update_layout(
    hovermode='x',  # Enable hover interaction
)

fig.show()

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>students with Marks 0 and 19 can be our outliars.</li>
# </ul></div>

# %%
grade1_col = df_coloumns[30]  # grade column
gender_col = df_coloumns[1]  # gender column

# Group by grade and gender, and count the percentage of occurrences
gender_counts = df.groupby([grade1_col, gender_col]).size().fillna(0).unstack()
gender_counts = (gender_counts*100)//df.shape[0]

# Create the figure
fig = go.Figure()

# Add bars for each gender as separate traces, creating a stacked effect
for gender in gender_counts.columns:
    fig.add_trace(
        go.Bar(
            x=gender_counts.index,
            y=gender_counts[gender],
            name=str(gender),
            marker_color="hotpink" if gender == "F" else "grey"  # Different colors for each gender
        )
    )

# Update layout with stacked option
fig.update_layout(
    title_text=f'Bar Chart of {grade1_col} by {gender_col}',
    xaxis_title='Grade 1',
    yaxis_title='percentage of students',
    hovermode='x',  # Enable hover interaction
)

fig.show()

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>Female students obtain higher marks Male students.</li>
# </ul></div>

# %%
grade1_col = df_coloumns[30]  # grade column
dropout_col = df_coloumns[33]  # dropout column

# Group by grade and dropout, and count the percentage of occurrences
dropout_counts = df.groupby([grade1_col, dropout_col]).size().fillna(0).unstack()
dropout_counts = (dropout_counts*100)//df.shape[0]

# Create the figure
fig = go.Figure()

# Add bars for each dropout as separate traces, creating a stacked effect
for dropout in dropout_counts.columns:
    fig.add_trace(
        go.Bar(
            x=dropout_counts.index,
            y=dropout_counts[dropout],
            name=str(dropout),
            marker_color="orange" if dropout == True else "teal"  # Different colors for each gender
        )
    )

# Update layout with stacked option
fig.update_layout(
    barmode='stack',  # Stack bars on top of each other
    title_text=f'Bar Chart of {grade1_col} by {dropout_col}',
    xaxis_title='Grade 1',
    yaxis_title='percentage of dropout students',
    hovermode='x',  # Enable hover interaction
)

fig.show()

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>students with higher marks are not in the catagory of dropout students.</li>
#     <li>students with lower marks are in the catagory of dropout students.</li>
#     <li>The reason of dropout of students with average marks should be something else.</li>
# </ul></div>

# %% [markdown]
# ### 5. Grade 2

# %%
print(f"IT IS A NUMERICAL VARIABLE. \nUNIQUE VALUES IN {df_coloumns[31]} :{df[df_coloumns[31]].unique()}")
# Out:
# IT IS A NUMERICAL VARIABLE.
# UNIQUE VALUES IN Grade_2 :[11 13 14 12 16 17  8 10 15  9  7  6 18 19  0  5]

# %%
fig = go.Figure(
        go.Histogram(
            x=df[df_coloumns[31]],
            marker = {"color": "blue",
                      "line":{"width":1,"color":"black"}},
            histnorm= "percent",
))

# Set overall title and axes labels
fig.update_layout(
    title_text=f'Distribution of {df_coloumns[31]}',
    xaxis_title='Grades',
    yaxis_title='percentage',
)

# Style subplot
fig.update_layout(
    hovermode='x',  # Enable hover interaction
)

fig.show()

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>The distribution of Grade 2 is symmetrical.</li>
#     <li>The person with Grade 0 can be our outliar.</li>
# </ul></div>

# %%
fig = go.Figure(
        go.Box(
            y=df[df_coloumns[31]],  # Note: y-axis for horizontal box plots
            boxpoints='all',  # Show all points
            marker_color="darkred",
            showlegend=False,
            name= "Box Plot"
    
))

# Set overall title and axes labels
fig.update_layout(
    title_text=f'Boxplot of {df_coloumns[31]}',
    yaxis_title='grades',
)

# Style subplot
fig.update_layout(
    hovermode='x',  # Enable hover interaction
)

fig.show()

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>students with Marks 0 and 19 can be our outliars.</li>
# </ul></div>

# %%
grade2_col = df_coloumns[31]  # grade column
gender_col = df_coloumns[1]  # gender column

# Group by grade and gender, and count the percentage of occurrences
gender_counts = df.groupby([grade2_col, gender_col]).size().fillna(0).unstack()
gender_counts = (gender_counts*100)//df.shape[0]

# Create the figure
fig = go.Figure()

# Add bars for each gender as separate traces, creating a stacked effect
for gender in gender_counts.columns:
    fig.add_trace(
        go.Bar(
            x=gender_counts.index,
            y=gender_counts[gender],
            name=str(gender),
            marker_color="mediumslateblue" if gender == "F" else "grey"  # Different colors for each gender
        )
    )

# Update layout with stacked option
fig.update_layout(
    title_text=f'Bar Chart of {grade2_col} by {gender_col}',
    xaxis_title='Grade 2',
    yaxis_title='percentage of students',
    hovermode='x',  # Enable hover interaction
)

fig.show()

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>Female students obtain higher marks Male students.</li>
# </ul></div>

# %%
grade2_col = df_coloumns[31]  # grade2 column
dropout_col = df_coloumns[33]  # dropout column

# Group by grade 2 and dropout, and count the percentage of occurrences
dropout_counts = df.groupby([grade2_col, dropout_col]).size().fillna(0).unstack()
dropout_counts = (dropout_counts*100)//df.shape[0]

# Create the figure
fig = go.Figure()

# Add bars for each dropout as separate traces, creating a stacked effect
for dropout in dropout_counts.columns:
    fig.add_trace(
        go.Bar(
            x=dropout_counts.index,
            y=dropout_counts[dropout],
            name=str(dropout),
            marker_color="orange" if dropout == True else "teal"  # Different colors for each gender
        )
    )

# Update layout with stacked option
fig.update_layout(
    barmode='stack',  # Stack bars on top of each other
    title_text=f'Bar Chart of {grade2_col} by {dropout_col}',
    xaxis_title='Grade 2',
    yaxis_title='percentage of dropout students',
    hovermode='x',  # Enable hover interaction
)

fig.show()

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>students with higher marks are not in the catagory of dropout students.</li>
#     <li>students with lower marks are in the catagory of dropout students.</li>
#     <li>The reason of dropout of students with average marks should be something else.</li>
# </ul></div>

# %% [markdown]
# ### 6. Final Grade

# %%
print(f"IT IS A NUMERICAL VARIABLE. \nUNIQUE VALUES IN {df_coloumns[32]} :{df[df_coloumns[32]].unique()}")
# Out:
# IT IS A NUMERICAL VARIABLE.
# UNIQUE VALUES IN Final_Grade :[11 12 14 13 17 15  7 10 16  9  8 18  6  0  1  5 19]

# %%
fig = go.Figure(
        go.Histogram(
            x=df[df_coloumns[32]],
            marker = {"color": "green",
                      "line":{"width":1,"color":"black"}},
            histnorm= "percent",
))

# Set overall title and axes labels
fig.update_layout(
    title_text=f'Distribution of {df_coloumns[32]}',
    xaxis_title='Final Grades',
    yaxis_title='percentage',
)

# Style subplot
fig.update_layout(
    hovermode='x',  # Enable hover interaction
)

fig.show()

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>The distribution of Final Grade is negatively skewed.</li>
#     <li>The person with Grade 0 and 1 can be our outliars.</li>
# </ul></div>

# %%
fig = go.Figure(
        go.Box(
            y=df[df_coloumns[32]],  # Note: y-axis for horizontal box plots
            boxpoints='all',  # Show all points
            marker_color="navy",
            showlegend=False,
            name= "Box Plot"
    
))

# Set overall title and axes labels
fig.update_layout(
    title_text=f'Boxplot of {df_coloumns[32]}',
    yaxis_title='grades',
)

# Style subplot
fig.update_layout(
    hovermode='x',  # Enable hover interaction
)

fig.show()

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>students with Marks 0 and 19 can be our outliars.</li>
# </ul></div>

# %%
finalgrade_col = df_coloumns[32]  # Final grade column
gender_col = df_coloumns[1]  # gender column

# Group by Final grade and gender, and count the percentage of occurrences
gender_counts = df.groupby([finalgrade_col, gender_col]).size().fillna(0).unstack()
gender_counts = (gender_counts*100)//df.shape[0]

# Create the figure
fig = go.Figure()

# Add bars for each gender as separate traces, creating a stacked effect
for gender in gender_counts.columns:
    fig.add_trace(
        go.Bar(
            x=gender_counts.index,
            y=gender_counts[gender],
            name=str(gender),
            marker_color="yellowgreen" if gender == "F" else "grey",  # Different colors for each gender
        )
    )

# Update layout with stacked option
fig.update_layout(
    title_text=f'Bar Chart of {finalgrade_col} by {gender_col}',
    xaxis_title='Grade 2',
    yaxis_title='percentage of students',
    hovermode='x',  # Enable hover interaction
)

fig.show()

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>Female students obtain higher marks than Male students.</li>
# </ul></div>

# %%
finalgrade_col = df_coloumns[32]  # Final grade column
dropout_col = df_coloumns[33]  # dropout column

# Group by final grade and dropout, and count the percentage of occurrences
dropout_counts = df.groupby([finalgrade_col, dropout_col]).size().fillna(0).unstack()
dropout_counts = (dropout_counts*100)//df.shape[0]

# Create the figure
fig = go.Figure()

# Add bars for each dropout as separate traces, creating a stacked effect
for dropout in dropout_counts.columns:
    fig.add_trace(
        go.Bar(
            x=dropout_counts.index,
            y=dropout_counts[dropout],
            name=str(dropout),
            marker_color="grey" if dropout == True else "red"  # Different colors for each gender
        )
    )

# Update layout with stacked option
fig.update_layout(
    barmode='stack',  # Stack bars on top of each other
    title_text=f'Bar Chart of {finalgrade_col} by {dropout_col}',
    xaxis_title='Final Grade',
    yaxis_title='percentage of dropout students',
    hovermode='x',  # Enable hover interaction
)

fig.show()

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>students with higher marks are not in the catagory of dropout students.</li>
#     <li>students with lower marks are in the catagory of dropout students.</li>
#     <li>The reason of dropout of students with average marks should be something else.</li>
# </ul></div>

# %%
columns = [df_coloumns[30], df_coloumns[31]]
target_col = df_coloumns[32]  

# Create figure with subplots and titles
fig = sp.make_subplots(rows=1, cols=2, subplot_titles=[f'Scatter plot of {col} and Final Grade' for col in columns])

# Add scatter traces and correlation annotations for each column
for i, col in enumerate(columns):
    # Calculate correlation
    correlation = df[target_col].corr(df[col])
    corr_text = f'Correlation: r = {correlation:.2f}'
    
    # Add scatter trace
    fig.add_trace(
        go.Scatter(
            x=df[target_col],
            y=df[col],
            mode='markers',
            marker=dict(
                size=10,
                color='navy',
                line=dict(color='black', width=1)
            ),
            name=col,
        ),  
        row=1, col=i+1,
)
    
    # Add correlation annotation in each subplot
    fig.add_annotation(
        text=corr_text,
        xref=f'x{i+1}', yref=f'y{i+1}',  # Correctly referencing subplot axes
        x=df[target_col].median(), y=df[col].max(),  # Adjust position within the plot area
        showarrow=False,
        font=dict(size=12, color='black'),
        align='center',
        bgcolor='#d9d9d9',
        opacity=0.8,
        
    )

# Set overall title and axes labels
fig.update_layout(
    title_text='SCATTER PLOT',
    showlegend=False
)

# Style subplots
fig.update_layout(
    hovermode='x',  # Enable hover interaction
    # margin=dict(l=20, r=20, b=20, t=70)
)

fig.show()

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>Grade 1 and Grade 2 are highly correlated with Final Grades.</li>
#     <li>Means Final grade is higly affected by previous Grades.</li>
# </ul></div>

# %% [markdown]
# <div
# style="
# font-family: 'Roboto', sans-serif;
# color:white;
# background-color:#3f37c9;
# padding:1%;
# border-radius:10px;
# font-size:2em;
# text-align:center
# ">
# Correlation Analysis
# </div>

# %%
fig, axes = plt.subplots()
plt.suptitle('correlation of Numerical variables with total')

columns = numerical_columns
correlation_matrix = df[columns].corr()

sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cbar=True)
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
