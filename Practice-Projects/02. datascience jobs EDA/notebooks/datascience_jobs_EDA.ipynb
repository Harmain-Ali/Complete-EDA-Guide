# %% [markdown]
# <div
# style="
# font-family: 'Roboto', sans-serif;
# color:white;
# background-color:#3f37c9;
# padding:1%;
# border-radius:10px;
# font-size:2em;
# text-align:center
# ">
# DATA JOBS DATASET
# </div>

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 📍 <b>NOTE</b>: This notebook is intended to :
# <ul>
#     <li>Provide exhaustive and comprehensive EDA on DATA JOBS dataset </li>
#     <li>Discuss the data-driven insights to the DATA JOBS dataset</li>
# </ul></div>

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔗 <b>Dataset link:</b> <a href="https://www.kaggle.com/datasets/hummaamqaasim/jobs-in-data?resource=">Click to download Dataset!</a>
# </div>

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# ⚓ <b>About the Dataset</b></br>
# <div>
# <p><strong>work_year</strong>: The year in which the data was recorded. This field indicates the temporal context of the data, important for understanding salary trends over time.</p>
# <p><strong>job_title</strong>: The specific title of the job role, like 'Data Scientist', 'Data Engineer', or 'Data Analyst'. This column is crucial for understanding the salary distribution across various specialized roles within the data field.</p>
# <p><strong>job_category</strong>: A classification of the job role into broader categories for easier analysis. This might include areas like 'Data Analysis', 'Machine Learning', 'Data Engineering', etc.</p>
# <p><strong>salary_currency</strong>: The currency in which the salary is paid, such as USD, EUR, etc. This is important for currency conversion and understanding the actual value of the salary in a global context.</p>
# <p><strong>salary</strong>: The annual gross salary of the role in the local currency. This raw salary figure is key for direct regional salary comparisons.</p>
# <p><strong>salary_in_usd</strong>: The annual gross salary converted to United States Dollars (USD). This uniform currency conversion aids in global salary comparisons and analyses.</p>
# <p><strong>employee_residence</strong>: The country of residence of the employee. This data point can be used to explore geographical salary differences and cost-of-living variations.</p>
# <p><strong>experience_level</strong>: Classifies the professional experience level of the employee. Common categories might include 'Entry-level', 'Mid-level', 'Senior', and 'Executive', providing insight into how experience influences salary in data-related roles.</p>
# <p><strong>employment_type</strong>: Specifies the type of employment, such as 'Full-time', 'Part-time', 'Contract', etc. This helps in analyzing how different employment arrangements affect salary structures.</p>
# <p><strong>work_setting</strong>: The work setting or environment, like 'Remote', 'In-person', or 'Hybrid'. This column reflects the impact of work settings on salary levels in the data industry.</p>
# <p><strong>company_location</strong>: The country where the company is located. It helps in analyzing how the location of the company affects salary structures.</p>
# <p><strong>company_size</strong>: The size of the employer company, often categorized into small (S), medium (M), and large (L) sizes. This allows for analysis of how company size influences salary.</p></div>
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

# %% [markdown]
# <div
# style="
# font-family: 'Roboto', sans-serif;
# color:white;
# background-color:#3f37c9;
# padding:1%;
# border-radius:10px;
# font-size:2em;
# text-align:center
# ">
# Initial Data Inspection
# </div>

# %%
dataframe = pd.read_csv('..\\data\\raw\\jobs_in_data.csv')

# %%
df = dataframe.copy()

# %%
df.head()
# Out:
#    work_year             job_title                    job_category  \
# 0       2023  Data DevOps Engineer                Data Engineering
# 1       2023        Data Architect  Data Architecture and Modeling
# 2       2023        Data Architect  Data Architecture and Modeling
# 3       2023        Data Scientist       Data Science and Research
# 4       2023        Data Scientist       Data Science and Research
#
#   salary_currency  salary  salary_in_usd employee_residence experience_level  \
# 0             EUR   88000          95012            Germany        Mid-level
# 1             USD  186000         186000      United States           Senior
# 2             USD   81800          81800      United States           Senior
# 3             USD  212000         212000      United States           Senior
# 4             USD   93300          93300      United States           Senior
#
#   employment_type work_setting company_location company_size
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9355 entries, 0 to 9354
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           9355 non-null   int64
#  1   job_title           9355 non-null   object
#  2   job_category        9355 non-null   object
#  3   salary_currency     9355 non-null   object
#  4   salary              9355 non-null   int64
#  5   salary_in_usd       9355 non-null   int64
#  6   employee_residence  9355 non-null   object
#  7   experience_level    9355 non-null   object
#  8   employment_type     9355 non-null   object
#  9   work_setting        9355 non-null   object
#  10  company_location    9355 non-null   object
#  11  company_size        9355 non-null   object
# dtypes: int64(3), object(9)
# memory usage: 877.2+ KB

# %%
df.isnull().sum()
# Out:
# work_year             0
# job_title             0
# job_category          0
# salary_currency       0
# salary                0
# salary_in_usd         0
# employee_residence    0
# experience_level      0
# employment_type       0
# work_setting          0
# company_location      0
# company_size          0
# dtype: int64

# %%
df.describe()
# Out:
#          work_year         salary  salary_in_usd
# count  9355.000000    9355.000000    9355.000000
# mean   2022.760449  149927.981293  150299.495564
# std       0.519470   63608.835387   63177.372024
# min    2020.000000   14000.000000   15000.000000
# 25%    2023.000000  105200.000000  105700.000000
# 50%    2023.000000  143860.000000  143000.000000
# 75%    2023.000000  187000.000000  186723.000000
# max    2023.000000  450000.000000  450000.000000

# %%
for i in df.columns:
    print('--'*50)
    print(i)
    print(df[i].unique())
# Out:
# ----------------------------------------------------------------------------------------------------
# work_year
# [2023 2022 2020 2021]
# ----------------------------------------------------------------------------------------------------
# job_title
# ['Data DevOps Engineer' 'Data Architect' 'Data Scientist'
#  'Machine Learning Researcher' 'Data Engineer' 'Machine Learning Engineer'
#  'Data Analyst' 'Analytics Engineer' 'Applied Scientist' 'BI Developer'
#  'Business Intelligence Engineer' 'Research Scientist' 'Research Analyst'
#  'Research Engineer' 'Data Science Engineer' 'Data Quality Analyst'
#  'Data Product Manager' 'Machine Learning Scientist' 'AI Engineer'
#  'MLOps Engineer' 'Deep Learning Engineer' 'Data Modeler'
#  'Data Product Owner' 'Data Science Consultant'
#  'Business Intelligence Analyst' 'AI Developer' 'Data Manager'
#  'ML Engineer' 'Data Science Director' 'Head of Data' 'BI Analyst'
#  'Data Management Analyst' 'Machine Learning Modeler' 'Data Specialist'
# ...

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>There are 9355 entries in the dataset.</li>
#     <li>There are 2 numeric, 9 categorical and 1 time variable in the dataset.</li>
#     <li>There are no missing values in the dataset.</li>
#     <li>salary_in_usd variable can be considered to be the target variable whereas other variables can describe the various effects on it.</li>
# </ul></div>

# %% [markdown]
# <div
# style="
# font-family: 'Roboto', sans-serif;
# color:white;
# background-color:#3f37c9;
# padding:1%;
# border-radius:10px;
# font-size:2em;
# text-align:center
# ">
# Cleaning Data for Analysis
# </div>

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>Here:</b>
# <ul>
#     <li>I am going to drop 2 columns (salary_currency and salary) because we will consider a universal unit USD in our analysis.</li>
#     <li>I wil drop the rows or entries taken in other than year 2023 because we will analyse salaries only for year 2023.</li>
# </ul></div>

# %%
# making a copy of df
df_droped = df.copy()

# %%
# droping the columns
df_droped.drop(['salary_currency', 'salary'], axis=1, inplace=True)

# %%
df_droped.drop(df_droped[df_droped['work_year'].isin([ 2022, 2020, 2021])].index,axis=0,inplace=True)

# %%
df_droped.head()
# Out:
#    work_year             job_title                    job_category  \
# 0       2023  Data DevOps Engineer                Data Engineering
# 1       2023        Data Architect  Data Architecture and Modeling
# 2       2023        Data Architect  Data Architecture and Modeling
# 3       2023        Data Scientist       Data Science and Research
# 4       2023        Data Scientist       Data Science and Research
#
#    salary_in_usd employee_residence experience_level employment_type  \
# 0          95012            Germany        Mid-level       Full-time
# 1         186000      United States           Senior       Full-time
# 2          81800      United States           Senior       Full-time
# 3         212000      United States           Senior       Full-time
# 4          93300      United States           Senior       Full-time
#
#   work_setting company_location company_size
# 0       Hybrid          Germany            L
# 1    In-person    United States            M
# ...

# %% [markdown]
# <div
# style="
# font-family: 'Roboto', sans-serif;
# color:white;
# background-color:#3f37c9;
# padding:1%;
# border-radius:10px;
# font-size:2em;
# text-align:center
# ">
# EDA of numarical variables
# </div>

# %%
plt.style.use('mystyle-v1')

# %%
# distribution of salaries in USD
plt.figure(figsize=(10,4))
plt.suptitle('Distribution of salaries_in_usd')
sns.histplot(data=df_droped, x='salary_in_usd', bins=20, kde=True)


plt.show()

# %%
# BOX PLOT SYNTAX IN SEABORN

plt.figure(figsize=(10,4))
plt.suptitle('Distribution of salaries_in_usd')
sns.boxplot(x=df_droped['salary_in_usd'], orient='h', showmeans=True)
plt.grid()

plt.show()

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>The variable salary_in_usd is possitively skewed.</li>
# </ul></div>

# %% [markdown]
# <div
# style="
# font-family: 'Roboto', sans-serif;
# color:white;
# background-color:#3f37c9;
# padding:1%;
# border-radius:10px;
# font-size:2em;
# text-align:center
# ">
# EDA of categorical variables
# </div>

# %%
# total number of rows in dataset
num_rows = df_droped.shape[0]
num_rows
# Out:
# 7453

# %%
# getting the catagorical variables
for col in df_droped.columns:
    if df_droped[col].dtype == 'O':
        print(f"'{col}'",end=',')
# Out:
# 'job_title','job_category','employee_residence','experience_level','employment_type','work_setting','company_location','company_size',

# %%
data_columns = ['job_title','job_category','employee_residence','experience_level','employment_type','work_setting','company_location','company_size',]

# %% [markdown]
# ### let us see all variables individualy

# %% [markdown]
# ### 1_ employee_residence

# %%
# finding unique values in the employee_residence variables
print(df_droped['employee_residence'].unique())
# Out:
# ['Germany' 'United States' 'United Kingdom' 'Canada' 'Spain' 'Ireland'
#  'South Africa' 'Poland' 'France' 'Czech Republic' 'Netherlands'
#  'Pakistan' 'Ukraine' 'Lithuania' 'Portugal' 'Australia' 'Uganda'
#  'Colombia' 'Italy' 'Slovenia' 'Romania' 'Greece' 'India' 'Latvia'
#  'Armenia' 'Croatia' 'Thailand' 'South Korea' 'Estonia' 'Turkey'
#  'Philippines' 'Brazil' 'Qatar' 'Kenya' 'Russia' 'Tunisia' 'Belgium'
#  'Switzerland' 'Andorra' 'Ecuador' 'Peru' 'Mexico' 'Moldova' 'Nigeria'
#  'Saudi Arabia' 'Ghana' 'Argentina' 'Egypt' 'Uzbekistan' 'Georgia'
#  'Central African Republic' 'Finland' 'Austria' 'Singapore' 'Sweden'
#  'Kuwait' 'Cyprus' 'Bosnia and Herzegovina']

# %%
employee_residence_groups=  df_droped.value_counts('employee_residence').index
employee_residence_counts = df_droped['employee_residence'].value_counts()

# %%
plt.figure(figsize=(18,4))
plt.suptitle('Employee residence and Percentages')
sns.barplot(x=employee_residence_groups, y=employee_residence_counts*100 // num_rows)
plt.ylabel('percentage')
plt.xticks(rotation= 90)
plt.show()

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>About 89% of information in the Dataset is related to US employes.</li>
# </ul></div>

# %% [markdown]
# ### 2_ company_location

# %%
# finding unique values in the company_location variables
print(df_droped['company_location'].unique())
# Out:
# ['Germany' 'United States' 'United Kingdom' 'Canada' 'Spain' 'Ireland'
#  'South Africa' 'Poland' 'France' 'Netherlands' 'Luxembourg' 'Lithuania'
#  'Portugal' 'Gibraltar' 'Australia' 'Colombia' 'Ukraine' 'Slovenia'
#  'Romania' 'Greece' 'India' 'Latvia' 'Russia' 'Italy' 'South Korea'
#  'Estonia' 'Czech Republic' 'Brazil' 'Qatar' 'Kenya' 'Denmark' 'Sweden'
#  'Turkey' 'Switzerland' 'Andorra' 'Ecuador' 'Mexico' 'Israel' 'Nigeria'
#  'Saudi Arabia' 'Ghana' 'Argentina' 'Japan' 'Central African Republic'
#  'Finland' 'Singapore' 'Croatia' 'Armenia' 'Bosnia and Herzegovina']

# %%
company_location_groups=  df_droped.value_counts('company_location').index
company_location_counts = df_droped['company_location'].value_counts()

# %%
plt.figure(figsize=(18,4))
plt.suptitle('Company locations and Percentages')
sns.barplot(x=company_location_groups, y=company_location_counts*100 // num_rows)
plt.ylabel('percentage')
plt.xticks(rotation= 90)
plt.show()

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>About 89% employes work in companies based in US.</li>
# </ul></div>

# %% [markdown]
# ### 3_ employment_type

# %%
# finding unique values in the employment_type variables
print(df_droped['employment_type'].unique())
# Out:
# ['Full-time' 'Part-time' 'Contract' 'Freelance']

# %%
employment_type_groups=  df_droped.value_counts('employment_type').index
employment_type_counts = df_droped['employment_type'].value_counts()

# %%
plt.figure(figsize=(10,4))
plt.suptitle('Employment types and Percentages')
sns.barplot(x=employment_type_groups, y=employment_type_counts*100 // num_rows)
plt.ylabel('percentage')
plt.show()

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>About 99% employes are working fulltime.</li>
# </ul></div>

# %% [markdown]
# ### 4_ job_category

# %%
# finding unique values in the job_category variables
print(df_droped['job_category'].unique())
# Out:
# ['Data Engineering' 'Data Architecture and Modeling'
#  'Data Science and Research' 'Machine Learning and AI' 'Data Analysis'
#  'Leadership and Management' 'BI and Visualization'
#  'Data Quality and Operations' 'Data Management and Strategy'
#  'Cloud and Database']

# %%
job_category_groups=  df_droped.value_counts('job_category').index
job_category_counts = df_droped['job_category'].value_counts()

# %%
plt.figure(figsize=(18,4))
plt.suptitle('Job categories and Percentages')
sns.barplot(x=job_category_counts*100 // num_rows, y=job_category_groups)
plt.xlabel('percentage')
plt.show()

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>About 32% jobs are of category Data Science and Research.</li>
#     <li>About 22% jobs are of category Data Engineering.</li>
#     <li>About 16% jobs are of category Machine Learning and AI.</li>
#     <li>About 15% jobs are of category Data Analysis.</li>
# </ul></div>

# %%
avg_salary_job_class = df_droped.groupby('job_category')['salary_in_usd'].mean().round(0).sort_values(ascending=False)

# %%
plt.figure(figsize=(18,4))
plt.suptitle('Average salaries across different job categories')
sns.barplot(x=avg_salary_job_class.values, y=avg_salary_job_class.index)
plt.xlabel('average salary')
plt.ylabel('job_category')
plt.show()

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b></br></br> Average salaries in different fields:
# <ul>
#   <li>Machine Learning and AI: $187,267 annually</li>
#   <li>Data Science and Research: $170,078 annually</li>
#   <li>Data Architecture and Modeling: $153,436 annually</li>
#   <li>Data Engineering: $149,676 annually</li>
#   <li>Leadership and Management: $147,428 annually</li>
#   <li>Cloud and Database: $141,667 annually</li>
#   <li>BI and Visualization: $135,990 annually</li>
#   <li>Data Analysis: $109,849 annually</li>
#   <li>Data Quality and Operations: $105,375 annually</li>
#   <li>Data Management and Strategy: $99,130 annually</li>
# </ul></div>

# %% [markdown]
# ### 5_ job_title

# %%
# finding unique values in the job_title variables
print(df_droped['job_title'].unique())
# Out:
# ['Data DevOps Engineer' 'Data Architect' 'Data Scientist'
#  'Machine Learning Researcher' 'Data Engineer' 'Machine Learning Engineer'
#  'Data Analyst' 'Analytics Engineer' 'Applied Scientist' 'BI Developer'
#  'Business Intelligence Engineer' 'Research Scientist' 'Research Analyst'
#  'Research Engineer' 'Data Science Engineer' 'Data Quality Analyst'
#  'Data Product Manager' 'Machine Learning Scientist' 'AI Engineer'
#  'MLOps Engineer' 'Deep Learning Engineer' 'Data Modeler'
#  'Data Product Owner' 'Data Science Consultant'
#  'Business Intelligence Analyst' 'AI Developer' 'Data Manager'
#  'ML Engineer' 'Data Science Director' 'Head of Data' 'BI Analyst'
#  'Data Management Analyst' 'Machine Learning Modeler' 'Data Specialist'
#  'BI Data Analyst' 'Data Integration Engineer'
#  'Business Intelligence Manager' 'Data Integration Specialist'
#  'Data Science Practitioner' 'Business Intelligence Developer' 'Data Lead'
# ...

# %%
job_title_groups=  list(df_droped.value_counts('job_title').index)
job_title_counts = df_droped['job_title'].value_counts()
job_title_counts_percentage = list(job_title_counts*100//num_rows)

# %%
plt.figure(figsize=(18,4))
plt.suptitle('Job titles and Percentages')
sns.barplot(x=job_title_counts_percentage[0:10], y=job_title_groups[0:10])
plt.xlabel('percentage')
plt.ylabel('Job Title')
plt.show()

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>About 22% employes are Data engineers.</li>
#     <li>About 20% employes are Data Scientist.</li>
#     <li>About 14% employees are Data Analyst.</li>
#     <li>About 11% employees are Machine Learning Engineer.</li>
# </ul></div>

# %% [markdown]
# ### 6_ experience_level

# %%
# finding unique values in the experience_level variables
print(df_droped['experience_level'].unique())
# Out:
# ['Mid-level' 'Senior' 'Executive' 'Entry-level']

# %%
experience_level_groups=  df_droped.value_counts('experience_level').index
experience_level_counts = df_droped['experience_level'].value_counts()

# %%
plt.figure(figsize=(18,4))
plt.suptitle('Experience levels and Percentages')
sns.barplot(y=experience_level_counts*100//num_rows, x=experience_level_groups)
plt.ylabel('percentage')
plt.show()

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>Almost 73% employes are of senior level.</li>
#     <li>Almost 18% employes are of mid-level.</li>
#     <li>Almost 4% employes are of entry-level.</li>
#     <li>Almost 3% are executives.</li>
# </ul></div>

# %%
avg_salary_exp = df_droped.groupby('experience_level')['salary_in_usd'].mean().round(0).sort_values(ascending=False)

# %%
plt.figure(figsize=(18,4))
plt.suptitle('Average salaries across different experience levels')
sns.barplot(x=avg_salary_exp.values, y=avg_salary_exp.index)
plt.xlabel('average salary')
plt.ylabel('Experience level')
plt.show()

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>On average Executives earn $189,496 annually.</li>
#     <li>On average senior employes earn $165,700 annually.</li>
#     <li>On average mid-level employes earn $122,527 annually.</li>
#     <li>On average entry_level employes earn $94,233 annually.</li>
# </ul></div>

# %% [markdown]
# ### 7_ company_size

# %%
# finding unique values in the company_size variables
print(df_droped['company_size'].unique())
# Out:
# ['L' 'M' 'S']

# %%
company_size_groups=  df_droped.value_counts('company_size').index
company_size_counts = df_droped['company_size'].value_counts()

# %%
plt.figure(figsize=(18,4))
plt.suptitle('Company sizes and Percentages')
sns.barplot(y=company_size_counts*100//num_rows, x=company_size_groups)
plt.xticks(['M','L','S'],['Medium','Large','Small'])
plt.ylabel('percentage')
plt.show()

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>About 93% companies are of Medium size.</li>
#     <li>Almost 5% companies are of Large size.</li>
# </ul></div>

# %%
avg_salary_org = df_droped.groupby('company_size')['salary_in_usd'].mean().round(0).sort_values(ascending=False)

# %%
plt.figure(figsize=(10,4))
plt.suptitle('Average salaries across different company sizes')
sns.barplot(y=avg_salary_org.values, x=avg_salary_org.index)
plt.xlabel('Company size')
plt.ylabel('average salary')
plt.show()

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>On average Medium sized companies pay $155,659 annually.</li>
#     <li>On average Large sized companies pay $153,962 annually.</li>
#     <li>On average Small sized companies pay $92,806 annually.</li>
# </ul>
# <b>Note:</b>The dataset dont have sufficient information about Large and Small companies.
# </div>

# %% [markdown]
# ### 8_ work_setting

# %%
# finding unique values in the work_setting variables
print(df_droped['work_setting'].unique())
# Out:
# ['Hybrid' 'In-person' 'Remote']

# %%
work_setting_groups=  df_droped.value_counts('work_setting').index
work_setting_counts = df_droped['work_setting'].value_counts()

# %%
plt.figure(figsize=(18,4))
plt.suptitle('Work settings and Percentages')
sns.barplot(y=work_setting_counts*100//num_rows, x=work_setting_groups)
plt.ylabel('percentage')
plt.show()

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>About 66% employes do in-person jobs.</li>
#     <li>Almost 32% employes do Remote jobs.</li>
# </ul></div>

# %%
avg_salary_work = df_droped.groupby('work_setting')['salary_in_usd'].mean().round(0).sort_values(ascending=False)

# %%
plt.figure(figsize=(10,4))
plt.suptitle('Average salaries across different work settings')
sns.barplot(y=avg_salary_work.values, x=avg_salary_work.index)
plt.xlabel('Work setting')
plt.ylabel('average salary')
plt.show()

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>On average In-person jobs pay $158,804 annually.</li>
#     <li>On average remote jobs pay $148,966 annually.</li>
#     <li>On average hybrid jobs pay $91,733 annually.</li>
# </ul>
# </div>

# %% [markdown]
# <div
# style="
# font-family: 'Roboto', sans-serif;
# color:white;
# background-color:#3f37c9;
# padding:1%;
# border-radius:10px;
# font-size:2em;
# text-align:center
# ">
# Multivariate analysis
# </div>

# %% [markdown]
# Let us study combination of different variables and salaries

# %%
plt.figure(figsize=(18,4))
plt.suptitle('Salaries Across Different Job Categories and Experience Levels')
sns.barplot(x=df_droped['job_category'],y=df_droped['salary_in_usd'],hue=df_droped['experience_level'])
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>Executives Earn More Than Others in Every Field.</li>
#     <li>Machine Learning and AI Jobs are most rewarding fields for every Experience Level.</li>
#     <li>Data Science and Research Jobs are second most rewarding fields for every Experience Level.</li>
# </ul>
# </div>

# %%
plt.figure(figsize=(18,4))
plt.suptitle('Salaries Across Different Job Categories and Company Sizes')
sns.barplot(x=df_droped['job_category'],y=df_droped['salary_in_usd'],hue=df_droped['company_size'])
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# 🔎 <b>We can see that:</b>
# <ul>
#     <li>Large sized companies pay More Than Others in Every Field.</li>
# </ul>
# </div>

# %% [markdown]
# <div
# style="
# /* color:white;
# background-color:#141414; */
# color:black;
# background-color:#d9d9d9;
# border-radius:10px;
# padding:1%;
# font-size:1em;
# border: 1px solid #3f37c9;
# ">
# <b><h1>Summary of EDA Conclusions:</h1></b>
#
#   <b>Demographic Insights:</b>
#   <ul>
#     <li>Approximately 89% of the dataset focuses on employees and companies in the United States.</li>
#     <li>The majority (99%) of employees work full-time.</li>
#   </ul>
#
#   <b>Job Categories:</b>
#   <ul>
#     <li>Data Science and Research is the most common job category (32%), followed by Data Engineering (22%) and Machine Learning and AI (16%).</li>
#   </ul>
#
#   <b>Average Salaries by Job Category:</b>
#   <ul>
#     <li>The highest-paying job categories are Machine Learning and AI, Data Science and Research, and Data Architecture and Modeling.</li>
#   </ul>
#
#   <b>Distribution of Employees by Job Role:</b>
#   <ul>
#     <li>Data Engineers constitute about 22% of the workforce, followed by Data Scientists (20%) and Data Analysts (14%).</li>
#   </ul>
#
#   <b>Experience Levels:</b>
#   <ul>
#     <li>Nearly 73% of employees are at the senior level, 18% at mid-level, and 4% at entry-level.</li>
#   </ul>
#
#   <b>Average Salaries by Experience Level:</b>
#   <ul>
#     <li>Executives earn the highest average salary ($189,496), followed by senior-level employees, mid-level employees, and entry-level employees.</li>
#   </ul>
#
#   <b>Company Sizes:</b>
#   <ul>
#     <li>About 93% of the companies are of medium size, with almost 5% being large-sized.</li>
#   </ul>
#
#   <b>Work Arrangements:</b>
#   <ul>
#     <li>Around 66% of employees work in-person, while 32% work remotely.</li>
#   </ul>
#
#   <b>Average Salaries by Work Arrangement:</b>
#   <ul>
#     <li>In-person jobs generally have higher average salaries compared to remote and hybrid jobs.</li>
#   </ul>
#
#   <b>Salary Disparities:</b>
#   <ul>
#     <li>Executives consistently earn more than other job roles in every field.</li>
#   </ul>
#
#   <b>Most Rewarding Fields:</b>
#   <ul>
#     <li>Machine Learning and AI jobs are the most rewarding for every experience level, followed by Data Science and Research jobs.</li>
#   </ul>
#
#   <b>Company Size Impact on Salary:</b>
#   <ul>
#     <li>Large-sized companies tend to pay more than others in every job category.</li>
#   </ul>
# </div>
